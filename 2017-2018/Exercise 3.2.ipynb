# %% [markdown]
# ## Exercise 3.2

# %% [markdown]
# Import the `datasets` library, whch contains a data set called `iris`. You can use the command `summary(iris)` to understand the variables inside this data set. An alternative to import a library is to use the `require()` function.

# %%
library(datasets)
summary(iris)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50

# %% [markdown]
# Access only to the petal length values

# %%
iris$Petal.Length
# Out:
#   [1] 1.4 1.4 1.3 1.5 1.4 1.7 1.4 1.5 1.4 1.5 1.5 1.6 1.4 1.1 1.2 1.5 1.3 1.4
#  [19] 1.7 1.5 1.7 1.5 1.0 1.7 1.9 1.6 1.6 1.5 1.4 1.6 1.6 1.5 1.5 1.4 1.5 1.2
#  [37] 1.3 1.4 1.3 1.5 1.3 1.3 1.3 1.6 1.9 1.4 1.6 1.4 1.5 1.4 4.7 4.5 4.9 4.0
#  [55] 4.6 4.5 4.7 3.3 4.6 3.9 3.5 4.2 4.0 4.7 3.6 4.4 4.5 4.1 4.5 3.9 4.8 4.0
#  [73] 4.9 4.7 4.3 4.4 4.8 5.0 4.5 3.5 3.8 3.7 3.9 5.1 4.5 4.5 4.7 4.4 4.1 4.0
#  [91] 4.4 4.6 4.0 3.3 4.2 4.2 4.2 4.3 3.0 4.1 6.0 5.1 5.9 5.6 5.8 6.6 4.5 6.3
# [109] 5.8 6.1 5.1 5.3 5.5 5.0 5.1 5.3 5.5 6.7 6.9 5.0 5.7 4.9 6.7 4.9 5.7 6.0
# [127] 4.8 4.9 5.6 5.8 6.1 6.4 5.6 5.1 5.6 6.1 5.6 5.5 4.8 5.4 5.6 5.1 5.1 5.9
# [145] 5.7 5.2 5.0 5.2 5.4 5.1

# %% [markdown]
# 1) Draw a histogram with 8 breaks for the petal lengths in the data.
# PS. Non so esattamente cosa faccia breaks(in teoria per il numero delle colonne) ma dice di metterlo, quindi easy!

# %%
 hist(iris$Petal.Length, breaks=8)
# Out:
# Plot with title “Histogram of iris$Petal.Length”

# %% [markdown]
# Include below the histogram a strip chart representing the actual values. Try to make it such that the  boxes do not overlap.

# %%
hist(iris$Petal.Length, breaks=8)
stripchart(iris$Petal.Length, add=TRUE, at=-1, method="stack")
# Out:
# Plot with title “Histogram of iris$Petal.Length”
